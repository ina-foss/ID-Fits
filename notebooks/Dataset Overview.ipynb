# %% [markdown]
# #     LFW Dataset Overview

# %%
# %pylab inline
from tools import *
from datasets import lfw
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = np.load("../data/lfw/lfw.npy")
showMosaic(data[:10], ncols=5)
del data

# %%
data = np.load("../data/lfw/lfwa.npy")
showMosaic(data[:10], ncols=5)
del data

# %%
data = lfw.preprocessData(np.load("../data/lfw/lfwa.npy"))
showMosaic(data[:10], ncols=5)
del data

# %%
data = np.load("../data/lfw/lfw_normalized_lbf_68_landmarks.npy")
showMosaic(data[:10], ncols=5)
del data

# %%
data = np.load("../data/lfw/lfw_normalized_csiro.npy")
showMosaic(data[:10], ncols=5)
del data

# %%
data = np.load("../data/lfw/lfw3d.npy")
showMosaic(data[:10], ncols=5)
del data
